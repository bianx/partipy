# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import csv
import matplotlib.tri as tri
import os, subprocess

#inputdir = '../gauss/vor_i_output_gnuplot/'
#inputdir = '../gauss/ttr_nx100_ny100_d008/'
inputdir = '../gauss/'
#inputdir = os.getcwd()
print(inputdir)

nx=50
ny=50
tot=nx*ny

x=np.zeros((ny, nx))
y=np.zeros((ny, nx))
z=np.zeros((ny, nx))

npts = 2508
fcount = 0
fmax   = 200

files = os.listdir(inputdir)
files.sort()
#data_path = '000074.grid'


zmin=0
zmax=20
lev = np.linspace(zmin, zmax, 21)
#print(lev)

for file in files:
    #print (file)
    if file.endswith('.grid'):
    
        fcount = fcount+1
        if fcount > fmax:
            break
    
        data_path=inputdir+'/'+file
        print ('processing file :', data_path)

        
        #read data
        line_count=0
        with open(data_path, 'r') as file:
            data = csv.reader(file, delimiter=' ')
            for row in data:
                ix = int(line_count/ny)
                iy = line_count%ny
                #print(line_count, ix, iy)
                x[ix, iy]=float(row[0])
                y[ix, iy]=float(row[1])
                z[ix, iy]=float(row[2])
                line_count += 1

        fig, ax = plt.subplots()
        #ax.plot(x, y, 'ko', ms=1) #show grid points
        ax.set(xlim=(-2.5, 2.5), ylim=(-2.5, 2.5))
        cp = ax.contourf(x, y, z, levels=lev)
        fig.colorbar(cp) # Add a colorbar to a plot
        #ax.clabel(cp, inline=1, fontsize=10)
        title="Contour with grid " + str(nx) + '*' + str(ny)
        ax.set_title(title)
        output='iso'+str(fcount-1).zfill(6)+'.png'
        print("output to "+output+"\n")
        fig.savefig(output)
        plt.close()
# Out:
# ../gauss/
# processing file : ../gauss//000000.grid
# output to iso000000.png
#
# processing file : ../gauss//000001.grid
# output to iso000001.png
#
# processing file : ../gauss//000002.grid
# output to iso000002.png
#
# processing file : ../gauss//000003.grid
# output to iso000003.png
#
# processing file : ../gauss//000004.grid
# output to iso000004.png
#
# processing file : ../gauss//000005.grid
# output to iso000005.png
#
# processing file : ../gauss//000006.grid
# output to iso000006.png
#
# processing file : ../gauss//000007.grid
# output to iso000007.png
#
# processing file : ../gauss//000008.grid
# output to iso000008.png
#
# processing file : ../gauss//000009.grid
# output to iso000009.png
#
# processing file : ../gauss//000010.grid
# output to iso000010.png
#
# processing file : ../gauss//000011.grid
# output to iso000011.png
#
# processing file : ../gauss//000012.grid
# output to iso000012.png
#
# processing file : ../gauss//000013.grid
# output to iso000013.png
#
# processing file : ../gauss//000014.grid
# output to iso000014.png
#
# processing file : ../gauss//000015.grid
# output to iso000015.png
#
# processing file : ../gauss//000016.grid
# output to iso000016.png
#
# processing file : ../gauss//000017.grid
# output to iso000017.png
#
# processing file : ../gauss//000018.grid
# output to iso000018.png
#
# processing file : ../gauss//000019.grid
# output to iso000019.png
#
# processing file : ../gauss//000020.grid
# output to iso000020.png
#
# processing file : ../gauss//000021.grid
# output to iso000021.png
#
# processing file : ../gauss//000022.grid
# output to iso000022.png
#
# processing file : ../gauss//000023.grid
# output to iso000023.png
#
# processing file : ../gauss//000024.grid
# output to iso000024.png
#
# processing file : ../gauss//000025.grid
# output to iso000025.png
#
# processing file : ../gauss//000026.grid
# output to iso000026.png
#
# processing file : ../gauss//000027.grid
# output to iso000027.png
#
# processing file : ../gauss//000028.grid
# output to iso000028.png
#
# processing file : ../gauss//000029.grid
# output to iso000029.png
#
# processing file : ../gauss//000030.grid
# output to iso000030.png
#
# processing file : ../gauss//000031.grid
# output to iso000031.png
#
# processing file : ../gauss//000032.grid
# output to iso000032.png
#
# processing file : ../gauss//000033.grid
# output to iso000033.png
#
# processing file : ../gauss//000034.grid
# output to iso000034.png
#
# processing file : ../gauss//000035.grid
# output to iso000035.png
#
# processing file : ../gauss//000036.grid
# output to iso000036.png
#
# processing file : ../gauss//000037.grid
# output to iso000037.png
#
# processing file : ../gauss//000038.grid
# output to iso000038.png
#
# processing file : ../gauss//000039.grid
# output to iso000039.png
#
# processing file : ../gauss//000040.grid
# output to iso000040.png
#
# processing file : ../gauss//000041.grid
# output to iso000041.png
#
# processing file : ../gauss//000042.grid
# output to iso000042.png
#
# processing file : ../gauss//000043.grid
# output to iso000043.png
#
# processing file : ../gauss//000044.grid
# output to iso000044.png
#
# processing file : ../gauss//000045.grid
# output to iso000045.png
#
# processing file : ../gauss//000046.grid
# output to iso000046.png
#
# processing file : ../gauss//000047.grid
# output to iso000047.png
#
# processing file : ../gauss//000048.grid
# output to iso000048.png
#
# processing file : ../gauss//000049.grid
# output to iso000049.png
#
# processing file : ../gauss//000050.grid
# output to iso000050.png
#
# processing file : ../gauss//000051.grid
# output to iso000051.png
#
# processing file : ../gauss//000052.grid
# output to iso000052.png
#
# processing file : ../gauss//000053.grid
# output to iso000053.png
#
# processing file : ../gauss//000054.grid
# output to iso000054.png
#
# processing file : ../gauss//000055.grid
# output to iso000055.png
#
# processing file : ../gauss//000056.grid
# output to iso000056.png
#
# processing file : ../gauss//000057.grid
# output to iso000057.png
#
# processing file : ../gauss//000058.grid
# output to iso000058.png
#
# processing file : ../gauss//000059.grid
# output to iso000059.png
#
# processing file : ../gauss//000060.grid
# output to iso000060.png
#
# processing file : ../gauss//000061.grid
# output to iso000061.png
#
# processing file : ../gauss//000062.grid
# output to iso000062.png
#
# processing file : ../gauss//000063.grid
# output to iso000063.png
#
# processing file : ../gauss//000064.grid
# output to iso000064.png
#
# processing file : ../gauss//000065.grid
# output to iso000065.png
#
# processing file : ../gauss//000066.grid
# output to iso000066.png
#
# processing file : ../gauss//000067.grid
# output to iso000067.png
#
# processing file : ../gauss//000068.grid
# output to iso000068.png
#
# processing file : ../gauss//000069.grid
# output to iso000069.png
#
# processing file : ../gauss//000070.grid
# output to iso000070.png
#
# processing file : ../gauss//000071.grid
# output to iso000071.png
#
# processing file : ../gauss//000072.grid
# output to iso000072.png
#
# processing file : ../gauss//000073.grid
# output to iso000073.png
#
# processing file : ../gauss//000074.grid
# output to iso000074.png
#
# processing file : ../gauss//000075.grid
# output to iso000075.png
#
# processing file : ../gauss//000076.grid
# output to iso000076.png
#
# processing file : ../gauss//000077.grid
# output to iso000077.png
#
# processing file : ../gauss//000078.grid
# output to iso000078.png
#
# processing file : ../gauss//000079.grid
# output to iso000079.png
#
# processing file : ../gauss//000080.grid
# output to iso000080.png
#
# processing file : ../gauss//000081.grid
# output to iso000081.png
#
# processing file : ../gauss//000082.grid
# output to iso000082.png
#
# processing file : ../gauss//000083.grid
# output to iso000083.png
#
# processing file : ../gauss//000084.grid
# output to iso000084.png
#
# processing file : ../gauss//000085.grid
# output to iso000085.png
#
# processing file : ../gauss//000086.grid
# output to iso000086.png
#
# processing file : ../gauss//000087.grid
# output to iso000087.png
#
# processing file : ../gauss//000088.grid
# output to iso000088.png
#
# processing file : ../gauss//000089.grid
# output to iso000089.png
#
# processing file : ../gauss//000090.grid
# output to iso000090.png
#
# processing file : ../gauss//000091.grid
# output to iso000091.png
#
# processing file : ../gauss//000092.grid
# output to iso000092.png
#
# processing file : ../gauss//000093.grid
# output to iso000093.png
#
# processing file : ../gauss//000094.grid
# output to iso000094.png
#
# processing file : ../gauss//000095.grid
# output to iso000095.png
#
# processing file : ../gauss//000096.grid
# output to iso000096.png
#
# processing file : ../gauss//000097.grid
# output to iso000097.png
#
# processing file : ../gauss//000098.grid
# output to iso000098.png
#
# processing file : ../gauss//000099.grid
# output to iso000099.png
#
# processing file : ../gauss//000100.grid
# output to iso000100.png
#
# processing file : ../gauss//000101.grid
# output to iso000101.png
#
# processing file : ../gauss//000102.grid
# output to iso000102.png
#
# processing file : ../gauss//000103.grid
# output to iso000103.png
#
# processing file : ../gauss//000104.grid
# output to iso000104.png
#
# processing file : ../gauss//000105.grid
# output to iso000105.png
#
# processing file : ../gauss//000106.grid
# output to iso000106.png
#
# processing file : ../gauss//000107.grid
# output to iso000107.png
#
# processing file : ../gauss//000108.grid
# output to iso000108.png
#
# processing file : ../gauss//000109.grid
# output to iso000109.png
#
# processing file : ../gauss//000110.grid
# output to iso000110.png
#
# processing file : ../gauss//000111.grid
# output to iso000111.png
#
# processing file : ../gauss//000112.grid
# output to iso000112.png
#
# processing file : ../gauss//000113.grid
# output to iso000113.png
#
# processing file : ../gauss//000114.grid
# output to iso000114.png
#
# processing file : ../gauss//000115.grid
# output to iso000115.png
#
# processing file : ../gauss//000116.grid
# output to iso000116.png
#
# processing file : ../gauss//000117.grid
# output to iso000117.png
#
# processing file : ../gauss//000118.grid
# output to iso000118.png
#
# processing file : ../gauss//000119.grid
# output to iso000119.png
#
# processing file : ../gauss//000120.grid
# output to iso000120.png
#
# processing file : ../gauss//000121.grid
# output to iso000121.png
#
# processing file : ../gauss//000122.grid
# output to iso000122.png
#
# processing file : ../gauss//000123.grid
# output to iso000123.png
#
# processing file : ../gauss//000124.grid
# output to iso000124.png
#
# processing file : ../gauss//000125.grid
# output to iso000125.png
# processing file : ../gauss//000126.grid
# output to iso000126.png
#
# processing file : ../gauss//000127.grid
# output to iso000127.png
#
# processing file : ../gauss//000128.grid
# output to iso000128.png
#
# processing file : ../gauss//000129.grid
# output to iso000129.png
#
# processing file : ../gauss//000130.grid
# output to iso000130.png
#
# processing file : ../gauss//000131.grid
# output to iso000131.png
#
# processing file : ../gauss//000132.grid
# output to iso000132.png
#
# processing file : ../gauss//000133.grid
# output to iso000133.png
#
# processing file : ../gauss//000134.grid
# output to iso000134.png
#
# processing file : ../gauss//000135.grid
# output to iso000135.png
#
# processing file : ../gauss//000136.grid
# output to iso000136.png
#
# processing file : ../gauss//000137.grid
# output to iso000137.png
#
# processing file : ../gauss//000138.grid
# output to iso000138.png
#
# processing file : ../gauss//000139.grid
# output to iso000139.png
#
# processing file : ../gauss//000140.grid
# output to iso000140.png
#
# processing file : ../gauss//000141.grid
# output to iso000141.png
#
# processing file : ../gauss//000142.grid
# output to iso000142.png
#
# processing file : ../gauss//000143.grid
# output to iso000143.png
#
# processing file : ../gauss//000144.grid
# output to iso000144.png
#
# processing file : ../gauss//000145.grid
# output to iso000145.png
#
# processing file : ../gauss//000146.grid
# output to iso000146.png
#
# processing file : ../gauss//000147.grid
# output to iso000147.png
#
# processing file : ../gauss//000148.grid
# output to iso000148.png
#
# processing file : ../gauss//000149.grid
# output to iso000149.png
#
# processing file : ../gauss//000150.grid
# output to iso000150.png
#
# processing file : ../gauss//000151.grid
# output to iso000151.png
#
# processing file : ../gauss//000152.grid
# output to iso000152.png
#
# processing file : ../gauss//000153.grid
# output to iso000153.png
#
# processing file : ../gauss//000154.grid
# output to iso000154.png
#
# processing file : ../gauss//000155.grid
# output to iso000155.png
#
# processing file : ../gauss//000156.grid
# output to iso000156.png
#
# processing file : ../gauss//000157.grid
# output to iso000157.png
#
# processing file : ../gauss//000158.grid
# output to iso000158.png
#
# processing file : ../gauss//000159.grid
# output to iso000159.png
#
# processing file : ../gauss//000160.grid
# output to iso000160.png
#
# processing file : ../gauss//000161.grid
# output to iso000161.png
#
# processing file : ../gauss//000162.grid
# output to iso000162.png
#
# processing file : ../gauss//000163.grid
# output to iso000163.png
#
# processing file : ../gauss//000164.grid
# output to iso000164.png
#
# processing file : ../gauss//000165.grid
# output to iso000165.png
#
# processing file : ../gauss//000166.grid
# output to iso000166.png
#
# processing file : ../gauss//000167.grid
# output to iso000167.png
#
# processing file : ../gauss//000168.grid
# output to iso000168.png
#
# processing file : ../gauss//000169.grid
# output to iso000169.png
#
# processing file : ../gauss//000170.grid
# output to iso000170.png
#
# processing file : ../gauss//000171.grid
# output to iso000171.png
#
# processing file : ../gauss//000172.grid
# output to iso000172.png
#
# processing file : ../gauss//000173.grid
# output to iso000173.png
#
# processing file : ../gauss//000174.grid
# output to iso000174.png
#
# processing file : ../gauss//000175.grid
# output to iso000175.png
#
# processing file : ../gauss//000176.grid
# output to iso000176.png
#
# processing file : ../gauss//000177.grid
# output to iso000177.png
#
# processing file : ../gauss//000178.grid
# output to iso000178.png
#
# processing file : ../gauss//000179.grid
# output to iso000179.png
#
# processing file : ../gauss//000180.grid
# output to iso000180.png
#
# processing file : ../gauss//000181.grid
# output to iso000181.png
#
# processing file : ../gauss//000182.grid
# output to iso000182.png
#
# processing file : ../gauss//000183.grid
# output to iso000183.png
#
# processing file : ../gauss//000184.grid
# output to iso000184.png
#
# processing file : ../gauss//000185.grid
# output to iso000185.png
#
# processing file : ../gauss//000186.grid
# output to iso000186.png
#
# processing file : ../gauss//000187.grid
# output to iso000187.png
#
# processing file : ../gauss//000188.grid
# output to iso000188.png
#
# processing file : ../gauss//000189.grid
# output to iso000189.png
#
# processing file : ../gauss//000190.grid
# output to iso000190.png
#
# processing file : ../gauss//000191.grid
# output to iso000191.png
#
# processing file : ../gauss//000192.grid
# output to iso000192.png
#
# processing file : ../gauss//000193.grid
# output to iso000193.png
#
# processing file : ../gauss//000194.grid
# output to iso000194.png
#
# processing file : ../gauss//000195.grid
# output to iso000195.png
#
# processing file : ../gauss//000196.grid
# output to iso000196.png
#
# processing file : ../gauss//000197.grid
# output to iso000197.png
#
# processing file : ../gauss//000198.grid
# output to iso000198.png
#
# processing file : ../gauss//000199.grid
# output to iso000199.png
