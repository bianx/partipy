# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import csv
import matplotlib.tri as tri
import os, subprocess

#inputdir = '../gauss/vor_i_output_gnuplot/'
inputdir = '../gauss/part_dx004_r012/'
#inputdir = '../gauss/'
#inputdir = os.getcwd()
print(inputdir)

nx=50
ny=50
tot=nx*ny


npts = 2508
t1 = 24 #total time
m  = 6000 #total step
dt = t1/m # step size
fcount = 0
fmax   = 601


files = os.listdir(inputdir)
files.sort()


zmin=0
zmax=0.032
lev = np.linspace(zmin, zmax, 21)
#print(lev)

for file in files:
    #print (file)
    if file.endswith('.dat'):
        
        step   = os.path.splitext(file)[0]
        step   = int(step)
        time   = step*dt
        fcount = fcount+1
        if fcount > fmax:
            break
    
        x=[]
        y=[]
        z=[]

        data_path=inputdir+'/'+file
        print ('processing file :', data_path)

        
        #read data
        line_count=0
        with open(data_path, 'r') as file:
            data = csv.reader(file, delimiter=' ')
            for row in data:
                ix = int(line_count/ny)
                iy = line_count%ny
                #print(line_count, ix, iy)
                x.append(float(row[0]))
                y.append(float(row[1]))
                z.append(float(row[2]))
                line_count += 1



        fig, ax = plt.subplots()
        cp=ax.tricontour(x, y, z, levels=lev)
        fig.colorbar(cp)
        #ax2.plot(x, y, 'ko', ms=0.5)
        ax.set(xlim=(-2.5, 2.5), ylim=(-2.5, 2.5))
        #ax.clabel(cp, inline=1, fontsize=10)
        title="#Particles:" + str(npts)+' dt:'+str(dt)+ ' step:'+str(step)+' time:'+str(round(time,2))
        
        ax.set_title(title)
        output='iso'+str(fcount-1).zfill(6)+'.png'
        print("output to "+output+"\n")
        fig.savefig(output, dpi=300)
        plt.close()
# Out:
# ../gauss/part_dx004_r012/
# processing file : ../gauss/part_dx004_r012//000000.dat
# output to iso000000.png
#
# processing file : ../gauss/part_dx004_r012//000010.dat
# output to iso000001.png
#
# processing file : ../gauss/part_dx004_r012//000020.dat
# output to iso000002.png
#
# processing file : ../gauss/part_dx004_r012//000030.dat
# output to iso000003.png
#
# processing file : ../gauss/part_dx004_r012//000040.dat
# output to iso000004.png
#
# processing file : ../gauss/part_dx004_r012//000050.dat
# output to iso000005.png
#
# processing file : ../gauss/part_dx004_r012//000060.dat
# output to iso000006.png
#
# processing file : ../gauss/part_dx004_r012//000070.dat
# output to iso000007.png
#
# processing file : ../gauss/part_dx004_r012//000080.dat
# output to iso000008.png
#
# processing file : ../gauss/part_dx004_r012//000090.dat
# output to iso000009.png
#
# processing file : ../gauss/part_dx004_r012//000100.dat
# output to iso000010.png
#
# processing file : ../gauss/part_dx004_r012//000110.dat
# output to iso000011.png
#
# processing file : ../gauss/part_dx004_r012//000120.dat
# output to iso000012.png
#
# processing file : ../gauss/part_dx004_r012//000130.dat
# output to iso000013.png
#
# processing file : ../gauss/part_dx004_r012//000140.dat
# output to iso000014.png
#
# processing file : ../gauss/part_dx004_r012//000150.dat
# output to iso000015.png
#
# processing file : ../gauss/part_dx004_r012//000160.dat
# output to iso000016.png
#
# processing file : ../gauss/part_dx004_r012//000170.dat
# output to iso000017.png
#
# processing file : ../gauss/part_dx004_r012//000180.dat
# output to iso000018.png
#
# processing file : ../gauss/part_dx004_r012//000190.dat
# output to iso000019.png
#
# processing file : ../gauss/part_dx004_r012//000200.dat
# output to iso000020.png
#
# processing file : ../gauss/part_dx004_r012//000210.dat
# output to iso000021.png
#
# processing file : ../gauss/part_dx004_r012//000220.dat
# output to iso000022.png
#
# processing file : ../gauss/part_dx004_r012//000230.dat
# output to iso000023.png
#
# processing file : ../gauss/part_dx004_r012//000240.dat
# output to iso000024.png
#
# processing file : ../gauss/part_dx004_r012//000250.dat
# output to iso000025.png
#
# processing file : ../gauss/part_dx004_r012//000260.dat
# output to iso000026.png
#
# processing file : ../gauss/part_dx004_r012//000270.dat
# output to iso000027.png
#
# processing file : ../gauss/part_dx004_r012//000280.dat
# output to iso000028.png
#
# processing file : ../gauss/part_dx004_r012//000290.dat
# output to iso000029.png
#
# processing file : ../gauss/part_dx004_r012//000300.dat
# output to iso000030.png
#
# processing file : ../gauss/part_dx004_r012//000310.dat
# output to iso000031.png
#
# processing file : ../gauss/part_dx004_r012//000320.dat
# output to iso000032.png
#
# processing file : ../gauss/part_dx004_r012//000330.dat
# output to iso000033.png
#
# processing file : ../gauss/part_dx004_r012//000340.dat
# output to iso000034.png
#
# processing file : ../gauss/part_dx004_r012//000350.dat
# output to iso000035.png
#
# processing file : ../gauss/part_dx004_r012//000360.dat
# output to iso000036.png
#
# processing file : ../gauss/part_dx004_r012//000370.dat
# output to iso000037.png
#
# processing file : ../gauss/part_dx004_r012//000380.dat
# output to iso000038.png
#
# processing file : ../gauss/part_dx004_r012//000390.dat
# output to iso000039.png
#
# processing file : ../gauss/part_dx004_r012//000400.dat
# output to iso000040.png
#
# processing file : ../gauss/part_dx004_r012//000410.dat
# output to iso000041.png
#
# processing file : ../gauss/part_dx004_r012//000420.dat
# output to iso000042.png
#
# processing file : ../gauss/part_dx004_r012//000430.dat
# output to iso000043.png
#
# processing file : ../gauss/part_dx004_r012//000440.dat
# output to iso000044.png
#
# processing file : ../gauss/part_dx004_r012//000450.dat
# output to iso000045.png
#
# processing file : ../gauss/part_dx004_r012//000460.dat
# output to iso000046.png
#
# processing file : ../gauss/part_dx004_r012//000470.dat
# output to iso000047.png
#
# processing file : ../gauss/part_dx004_r012//000480.dat
# output to iso000048.png
#
# processing file : ../gauss/part_dx004_r012//000490.dat
# output to iso000049.png
#
# processing file : ../gauss/part_dx004_r012//000500.dat
# output to iso000050.png
#
# processing file : ../gauss/part_dx004_r012//000510.dat
# output to iso000051.png
#
# processing file : ../gauss/part_dx004_r012//000520.dat
# output to iso000052.png
#
# processing file : ../gauss/part_dx004_r012//000530.dat
# output to iso000053.png
#
# processing file : ../gauss/part_dx004_r012//000540.dat
# output to iso000054.png
#
# processing file : ../gauss/part_dx004_r012//000550.dat
# output to iso000055.png
#
# processing file : ../gauss/part_dx004_r012//000560.dat
# output to iso000056.png
#
# processing file : ../gauss/part_dx004_r012//000570.dat
# output to iso000057.png
#
# processing file : ../gauss/part_dx004_r012//000580.dat
# output to iso000058.png
#
# processing file : ../gauss/part_dx004_r012//000590.dat
# output to iso000059.png
#
# processing file : ../gauss/part_dx004_r012//000600.dat
# output to iso000060.png
#
# processing file : ../gauss/part_dx004_r012//000610.dat
# output to iso000061.png
#
# processing file : ../gauss/part_dx004_r012//000620.dat
# output to iso000062.png
#
# processing file : ../gauss/part_dx004_r012//000630.dat
# output to iso000063.png
#
# processing file : ../gauss/part_dx004_r012//000640.dat
# output to iso000064.png
#
# processing file : ../gauss/part_dx004_r012//000650.dat
# output to iso000065.png
#
# processing file : ../gauss/part_dx004_r012//000660.dat
# output to iso000066.png
#
# processing file : ../gauss/part_dx004_r012//000670.dat
# output to iso000067.png
#
# processing file : ../gauss/part_dx004_r012//000680.dat
# output to iso000068.png
#
# processing file : ../gauss/part_dx004_r012//000690.dat
# output to iso000069.png
#
# processing file : ../gauss/part_dx004_r012//000700.dat
# output to iso000070.png
#
# processing file : ../gauss/part_dx004_r012//000710.dat
# output to iso000071.png
#
# processing file : ../gauss/part_dx004_r012//000720.dat
# output to iso000072.png
#
# processing file : ../gauss/part_dx004_r012//000730.dat
# output to iso000073.png
#
# processing file : ../gauss/part_dx004_r012//000740.dat
# output to iso000074.png
#
# processing file : ../gauss/part_dx004_r012//000750.dat
# output to iso000075.png
#
# processing file : ../gauss/part_dx004_r012//000760.dat
# output to iso000076.png
#
# processing file : ../gauss/part_dx004_r012//000770.dat
# output to iso000077.png
#
# processing file : ../gauss/part_dx004_r012//000780.dat
# output to iso000078.png
#
# processing file : ../gauss/part_dx004_r012//000790.dat
# output to iso000079.png
#
# processing file : ../gauss/part_dx004_r012//000800.dat
# output to iso000080.png
#
# processing file : ../gauss/part_dx004_r012//000810.dat
# output to iso000081.png
#
# processing file : ../gauss/part_dx004_r012//000820.dat
# output to iso000082.png
#
# processing file : ../gauss/part_dx004_r012//000830.dat
# output to iso000083.png
#
# processing file : ../gauss/part_dx004_r012//000840.dat
# output to iso000084.png
#
# processing file : ../gauss/part_dx004_r012//000850.dat
# output to iso000085.png
#
# processing file : ../gauss/part_dx004_r012//000860.dat
# output to iso000086.png
#
# processing file : ../gauss/part_dx004_r012//000870.dat
# output to iso000087.png
#
# processing file : ../gauss/part_dx004_r012//000880.dat
# output to iso000088.png
#
# processing file : ../gauss/part_dx004_r012//000890.dat
# output to iso000089.png
#
# processing file : ../gauss/part_dx004_r012//000900.dat
# output to iso000090.png
#
# processing file : ../gauss/part_dx004_r012//000910.dat
# output to iso000091.png
#
# processing file : ../gauss/part_dx004_r012//000920.dat
# output to iso000092.png
#
# processing file : ../gauss/part_dx004_r012//000930.dat
# output to iso000093.png
#
# processing file : ../gauss/part_dx004_r012//000940.dat
# output to iso000094.png
#
# processing file : ../gauss/part_dx004_r012//000950.dat
# output to iso000095.png
#
# processing file : ../gauss/part_dx004_r012//000960.dat
# output to iso000096.png
#
# processing file : ../gauss/part_dx004_r012//000970.dat
# output to iso000097.png
#
# processing file : ../gauss/part_dx004_r012//000980.dat
# output to iso000098.png
#
# processing file : ../gauss/part_dx004_r012//000990.dat
# output to iso000099.png
#
# processing file : ../gauss/part_dx004_r012//001000.dat
# output to iso000100.png
#
# processing file : ../gauss/part_dx004_r012//001010.dat
# output to iso000101.png
#
# processing file : ../gauss/part_dx004_r012//001020.dat
# output to iso000102.png
#
# processing file : ../gauss/part_dx004_r012//001030.dat
# output to iso000103.png
#
# processing file : ../gauss/part_dx004_r012//001040.dat
# output to iso000104.png
#
# processing file : ../gauss/part_dx004_r012//001050.dat
# output to iso000105.png
#
# processing file : ../gauss/part_dx004_r012//001060.dat
# output to iso000106.png
#
# processing file : ../gauss/part_dx004_r012//001070.dat
# output to iso000107.png
#
# processing file : ../gauss/part_dx004_r012//001080.dat
# output to iso000108.png
#
# processing file : ../gauss/part_dx004_r012//001090.dat
# output to iso000109.png
#
# processing file : ../gauss/part_dx004_r012//001100.dat
# output to iso000110.png
#
# processing file : ../gauss/part_dx004_r012//001110.dat
# output to iso000111.png
#
# processing file : ../gauss/part_dx004_r012//001120.dat
# output to iso000112.png
#
# processing file : ../gauss/part_dx004_r012//001130.dat
# output to iso000113.png
#
# processing file : ../gauss/part_dx004_r012//001140.dat
# output to iso000114.png
#
# processing file : ../gauss/part_dx004_r012//001150.dat
# output to iso000115.png
#
# processing file : ../gauss/part_dx004_r012//001160.dat
# output to iso000116.png
#
# processing file : ../gauss/part_dx004_r012//001170.dat
# output to iso000117.png
#
# processing file : ../gauss/part_dx004_r012//001180.dat
# output to iso000118.png
#
# processing file : ../gauss/part_dx004_r012//001190.dat
# output to iso000119.png
#
# processing file : ../gauss/part_dx004_r012//001200.dat
# output to iso000120.png
#
# processing file : ../gauss/part_dx004_r012//001210.dat
# output to iso000121.png
#
# processing file : ../gauss/part_dx004_r012//001220.dat
# output to iso000122.png
#
# processing file : ../gauss/part_dx004_r012//001230.dat
# output to iso000123.png
#
# processing file : ../gauss/part_dx004_r012//001240.dat
# output to iso000124.png
#
# processing file : ../gauss/part_dx004_r012//001250.dat
# output to iso000125.png
#
# processing file : ../gauss/part_dx004_r012//001260.dat
# output to iso000126.png
#
# processing file : ../gauss/part_dx004_r012//001270.dat
# output to iso000127.png
#
# processing file : ../gauss/part_dx004_r012//001280.dat
# output to iso000128.png
#
# processing file : ../gauss/part_dx004_r012//001290.dat
# output to iso000129.png
#
# processing file : ../gauss/part_dx004_r012//001300.dat
# output to iso000130.png
#
# processing file : ../gauss/part_dx004_r012//001310.dat
# output to iso000131.png
#
# processing file : ../gauss/part_dx004_r012//001320.dat
# output to iso000132.png
#
# processing file : ../gauss/part_dx004_r012//001330.dat
# output to iso000133.png
#
# processing file : ../gauss/part_dx004_r012//001340.dat
# output to iso000134.png
#
# processing file : ../gauss/part_dx004_r012//001350.dat
# output to iso000135.png
#
# processing file : ../gauss/part_dx004_r012//001360.dat
# output to iso000136.png
#
# processing file : ../gauss/part_dx004_r012//001370.dat
# output to iso000137.png
#
# processing file : ../gauss/part_dx004_r012//001380.dat
# output to iso000138.png
#
# processing file : ../gauss/part_dx004_r012//001390.dat
# output to iso000139.png
#
# processing file : ../gauss/part_dx004_r012//001400.dat
# output to iso000140.png
#
# processing file : ../gauss/part_dx004_r012//001410.dat
# output to iso000141.png
#
# processing file : ../gauss/part_dx004_r012//001420.dat
# output to iso000142.png
#
# processing file : ../gauss/part_dx004_r012//001430.dat
# output to iso000143.png
#
# processing file : ../gauss/part_dx004_r012//001440.dat
# output to iso000144.png
#
# processing file : ../gauss/part_dx004_r012//001450.dat
# output to iso000145.png
#
# processing file : ../gauss/part_dx004_r012//001460.dat
# output to iso000146.png
#
# processing file : ../gauss/part_dx004_r012//001470.dat
# output to iso000147.png
#
# processing file : ../gauss/part_dx004_r012//001480.dat
# output to iso000148.png
#
# processing file : ../gauss/part_dx004_r012//001490.dat
# output to iso000149.png
#
# processing file : ../gauss/part_dx004_r012//001500.dat
# output to iso000150.png
#
# processing file : ../gauss/part_dx004_r012//001510.dat
# output to iso000151.png
#
# processing file : ../gauss/part_dx004_r012//001520.dat
# output to iso000152.png
#
# processing file : ../gauss/part_dx004_r012//001530.dat
# output to iso000153.png
#
# processing file : ../gauss/part_dx004_r012//001540.dat
# output to iso000154.png
#
# processing file : ../gauss/part_dx004_r012//001550.dat
# output to iso000155.png
#
# processing file : ../gauss/part_dx004_r012//001560.dat
# output to iso000156.png
#
# processing file : ../gauss/part_dx004_r012//001570.dat
# output to iso000157.png
#
# processing file : ../gauss/part_dx004_r012//001580.dat
# output to iso000158.png
#
# processing file : ../gauss/part_dx004_r012//001590.dat
# output to iso000159.png
#
# processing file : ../gauss/part_dx004_r012//001600.dat
# output to iso000160.png
#
# processing file : ../gauss/part_dx004_r012//001610.dat
# output to iso000161.png
#
# processing file : ../gauss/part_dx004_r012//001620.dat
# output to iso000162.png
#
# processing file : ../gauss/part_dx004_r012//001630.dat
# output to iso000163.png
#
# processing file : ../gauss/part_dx004_r012//001640.dat
# output to iso000164.png
#
# processing file : ../gauss/part_dx004_r012//001650.dat
# output to iso000165.png
#
# processing file : ../gauss/part_dx004_r012//001660.dat
# output to iso000166.png
#
# processing file : ../gauss/part_dx004_r012//001670.dat
# output to iso000167.png
#
# processing file : ../gauss/part_dx004_r012//001680.dat
# output to iso000168.png
#
# processing file : ../gauss/part_dx004_r012//001690.dat
# output to iso000169.png
#
# processing file : ../gauss/part_dx004_r012//001700.dat
# output to iso000170.png
#
# processing file : ../gauss/part_dx004_r012//001710.dat
# output to iso000171.png
#
# processing file : ../gauss/part_dx004_r012//001720.dat
# output to iso000172.png
#
# processing file : ../gauss/part_dx004_r012//001730.dat
# output to iso000173.png
#
# processing file : ../gauss/part_dx004_r012//001740.dat
# output to iso000174.png
#
# processing file : ../gauss/part_dx004_r012//001750.dat
# output to iso000175.png
#
# processing file : ../gauss/part_dx004_r012//001760.dat
# output to iso000176.png
#
# processing file : ../gauss/part_dx004_r012//001770.dat
# output to iso000177.png
#
# processing file : ../gauss/part_dx004_r012//001780.dat
# output to iso000178.png
#
# processing file : ../gauss/part_dx004_r012//001790.dat
# output to iso000179.png
#
# processing file : ../gauss/part_dx004_r012//001800.dat
# output to iso000180.png
#
# processing file : ../gauss/part_dx004_r012//001810.dat
# output to iso000181.png
#
# processing file : ../gauss/part_dx004_r012//001820.dat
# output to iso000182.png
#
# processing file : ../gauss/part_dx004_r012//001830.dat
# output to iso000183.png
#
# processing file : ../gauss/part_dx004_r012//001840.dat
# output to iso000184.png
#
# processing file : ../gauss/part_dx004_r012//001850.dat
# output to iso000185.png
#
# processing file : ../gauss/part_dx004_r012//001860.dat
# output to iso000186.png
#
# processing file : ../gauss/part_dx004_r012//001870.dat
# output to iso000187.png
#
# processing file : ../gauss/part_dx004_r012//001880.dat
# output to iso000188.png
#
# processing file : ../gauss/part_dx004_r012//001890.dat
# output to iso000189.png
#
# processing file : ../gauss/part_dx004_r012//001900.dat
# output to iso000190.png
#
# processing file : ../gauss/part_dx004_r012//001910.dat
# output to iso000191.png
#
# processing file : ../gauss/part_dx004_r012//001920.dat
# output to iso000192.png
#
# processing file : ../gauss/part_dx004_r012//001930.dat
# output to iso000193.png
#
# processing file : ../gauss/part_dx004_r012//001940.dat
# output to iso000194.png
#
# processing file : ../gauss/part_dx004_r012//001950.dat
# output to iso000195.png
#
# processing file : ../gauss/part_dx004_r012//001960.dat
# output to iso000196.png
#
# processing file : ../gauss/part_dx004_r012//001970.dat
# output to iso000197.png
#
# processing file : ../gauss/part_dx004_r012//001980.dat
# output to iso000198.png
#
# processing file : ../gauss/part_dx004_r012//001990.dat
# output to iso000199.png
#
# processing file : ../gauss/part_dx004_r012//002000.dat
# output to iso000200.png
#
# processing file : ../gauss/part_dx004_r012//002010.dat
# output to iso000201.png
#
# processing file : ../gauss/part_dx004_r012//002020.dat
# output to iso000202.png
#
# processing file : ../gauss/part_dx004_r012//002030.dat
# output to iso000203.png
#
# processing file : ../gauss/part_dx004_r012//002040.dat
# output to iso000204.png
#
# processing file : ../gauss/part_dx004_r012//002050.dat
# output to iso000205.png
#
# processing file : ../gauss/part_dx004_r012//002060.dat
# output to iso000206.png
#
# processing file : ../gauss/part_dx004_r012//002070.dat
# output to iso000207.png
#
# processing file : ../gauss/part_dx004_r012//002080.dat
# output to iso000208.png
#
# processing file : ../gauss/part_dx004_r012//002090.dat
# output to iso000209.png
#
# processing file : ../gauss/part_dx004_r012//002100.dat
# output to iso000210.png
#
# processing file : ../gauss/part_dx004_r012//002110.dat
# output to iso000211.png
#
# processing file : ../gauss/part_dx004_r012//002120.dat
# output to iso000212.png
#
# processing file : ../gauss/part_dx004_r012//002130.dat
# output to iso000213.png
#
# processing file : ../gauss/part_dx004_r012//002140.dat
# output to iso000214.png
#
# processing file : ../gauss/part_dx004_r012//002150.dat
# output to iso000215.png
#
# processing file : ../gauss/part_dx004_r012//002160.dat
# output to iso000216.png
#
# processing file : ../gauss/part_dx004_r012//002170.dat
# output to iso000217.png
#
# processing file : ../gauss/part_dx004_r012//002180.dat
# output to iso000218.png
#
# processing file : ../gauss/part_dx004_r012//002190.dat
# output to iso000219.png
#
# processing file : ../gauss/part_dx004_r012//002200.dat
# output to iso000220.png
#
# processing file : ../gauss/part_dx004_r012//002210.dat
# output to iso000221.png
#
# processing file : ../gauss/part_dx004_r012//002220.dat
# output to iso000222.png
#
# processing file : ../gauss/part_dx004_r012//002230.dat
# output to iso000223.png
#
# processing file : ../gauss/part_dx004_r012//002240.dat
# output to iso000224.png
#
# processing file : ../gauss/part_dx004_r012//002250.dat
# output to iso000225.png
#
# processing file : ../gauss/part_dx004_r012//002260.dat
# output to iso000226.png
#
# processing file : ../gauss/part_dx004_r012//002270.dat
# output to iso000227.png
#
# processing file : ../gauss/part_dx004_r012//002280.dat
# output to iso000228.png
#
# processing file : ../gauss/part_dx004_r012//002290.dat
# output to iso000229.png
#
# processing file : ../gauss/part_dx004_r012//002300.dat
# output to iso000230.png
#
# processing file : ../gauss/part_dx004_r012//002310.dat
# output to iso000231.png
#
# processing file : ../gauss/part_dx004_r012//002320.dat
# output to iso000232.png
#
# processing file : ../gauss/part_dx004_r012//002330.dat
# output to iso000233.png
#
# processing file : ../gauss/part_dx004_r012//002340.dat
# output to iso000234.png
#
# processing file : ../gauss/part_dx004_r012//002350.dat
# output to iso000235.png
#
# processing file : ../gauss/part_dx004_r012//002360.dat
# output to iso000236.png
#
# processing file : ../gauss/part_dx004_r012//002370.dat
# output to iso000237.png
#
# processing file : ../gauss/part_dx004_r012//002380.dat
# output to iso000238.png
#
# processing file : ../gauss/part_dx004_r012//002390.dat
# output to iso000239.png
#
# processing file : ../gauss/part_dx004_r012//002400.dat
# output to iso000240.png
#
# processing file : ../gauss/part_dx004_r012//002410.dat
# output to iso000241.png
#
# processing file : ../gauss/part_dx004_r012//002420.dat
# output to iso000242.png
#
# processing file : ../gauss/part_dx004_r012//002430.dat
# output to iso000243.png
#
# processing file : ../gauss/part_dx004_r012//002440.dat
# output to iso000244.png
#
# processing file : ../gauss/part_dx004_r012//002450.dat
# output to iso000245.png
#
# processing file : ../gauss/part_dx004_r012//002460.dat
# output to iso000246.png
#
# processing file : ../gauss/part_dx004_r012//002470.dat
# output to iso000247.png
#
# processing file : ../gauss/part_dx004_r012//002480.dat
# output to iso000248.png
#
# processing file : ../gauss/part_dx004_r012//002490.dat
# output to iso000249.png
#
# processing file : ../gauss/part_dx004_r012//002500.dat
# output to iso000250.png
#
# processing file : ../gauss/part_dx004_r012//002510.dat
# output to iso000251.png
#
# processing file : ../gauss/part_dx004_r012//002520.dat
# output to iso000252.png
#
# processing file : ../gauss/part_dx004_r012//002530.dat
# output to iso000253.png
#
# processing file : ../gauss/part_dx004_r012//002540.dat
# output to iso000254.png
#
# processing file : ../gauss/part_dx004_r012//002550.dat
# output to iso000255.png
#
# processing file : ../gauss/part_dx004_r012//002560.dat
# output to iso000256.png
#
# processing file : ../gauss/part_dx004_r012//002570.dat
# output to iso000257.png
#
# processing file : ../gauss/part_dx004_r012//002580.dat
# output to iso000258.png
#
# processing file : ../gauss/part_dx004_r012//002590.dat
# output to iso000259.png
#
# processing file : ../gauss/part_dx004_r012//002600.dat
# output to iso000260.png
#
# processing file : ../gauss/part_dx004_r012//002610.dat
# output to iso000261.png
#
# processing file : ../gauss/part_dx004_r012//002620.dat
# output to iso000262.png
#
# processing file : ../gauss/part_dx004_r012//002630.dat
# output to iso000263.png
#
# processing file : ../gauss/part_dx004_r012//002640.dat
# output to iso000264.png
#
# processing file : ../gauss/part_dx004_r012//002650.dat
# output to iso000265.png
#
# processing file : ../gauss/part_dx004_r012//002660.dat
# output to iso000266.png
#
# processing file : ../gauss/part_dx004_r012//002670.dat
# output to iso000267.png
#
# processing file : ../gauss/part_dx004_r012//002680.dat
# output to iso000268.png
#
# processing file : ../gauss/part_dx004_r012//002690.dat
# output to iso000269.png
#
# processing file : ../gauss/part_dx004_r012//002700.dat
# output to iso000270.png
#
# processing file : ../gauss/part_dx004_r012//002710.dat
# output to iso000271.png
#
# processing file : ../gauss/part_dx004_r012//002720.dat
# output to iso000272.png
#
# processing file : ../gauss/part_dx004_r012//002730.dat
# output to iso000273.png
#
# processing file : ../gauss/part_dx004_r012//002740.dat
# output to iso000274.png
#
# processing file : ../gauss/part_dx004_r012//002750.dat
# output to iso000275.png
#
# processing file : ../gauss/part_dx004_r012//002760.dat
# output to iso000276.png
#
# processing file : ../gauss/part_dx004_r012//002770.dat
# output to iso000277.png
#
# processing file : ../gauss/part_dx004_r012//002780.dat
# output to iso000278.png
#
# processing file : ../gauss/part_dx004_r012//002790.dat
# output to iso000279.png
#
# processing file : ../gauss/part_dx004_r012//002800.dat
# output to iso000280.png
#
# processing file : ../gauss/part_dx004_r012//002810.dat
# output to iso000281.png
#
# processing file : ../gauss/part_dx004_r012//002820.dat
# output to iso000282.png
#
# processing file : ../gauss/part_dx004_r012//002830.dat
# output to iso000283.png
#
# processing file : ../gauss/part_dx004_r012//002840.dat
# output to iso000284.png
#
# processing file : ../gauss/part_dx004_r012//002850.dat
# output to iso000285.png
#
# processing file : ../gauss/part_dx004_r012//002860.dat
# output to iso000286.png
#
# processing file : ../gauss/part_dx004_r012//002870.dat
# output to iso000287.png
#
# processing file : ../gauss/part_dx004_r012//002880.dat
# output to iso000288.png
#
# processing file : ../gauss/part_dx004_r012//002890.dat
# output to iso000289.png
#
# processing file : ../gauss/part_dx004_r012//002900.dat
# output to iso000290.png
#
# processing file : ../gauss/part_dx004_r012//002910.dat
# output to iso000291.png
#
# processing file : ../gauss/part_dx004_r012//002920.dat
# output to iso000292.png
#
# processing file : ../gauss/part_dx004_r012//002930.dat
# output to iso000293.png
#
# processing file : ../gauss/part_dx004_r012//002940.dat
# output to iso000294.png
#
# processing file : ../gauss/part_dx004_r012//002950.dat
# output to iso000295.png
#
# processing file : ../gauss/part_dx004_r012//002960.dat
# output to iso000296.png
#
# processing file : ../gauss/part_dx004_r012//002970.dat
# output to iso000297.png
#
# processing file : ../gauss/part_dx004_r012//002980.dat
# output to iso000298.png
#
# processing file : ../gauss/part_dx004_r012//002990.dat
# output to iso000299.png
#
# processing file : ../gauss/part_dx004_r012//003000.dat
# output to iso000300.png
#
# processing file : ../gauss/part_dx004_r012//003010.dat
# output to iso000301.png
#
# processing file : ../gauss/part_dx004_r012//003020.dat
# output to iso000302.png
#
# processing file : ../gauss/part_dx004_r012//003030.dat
# output to iso000303.png
#
# processing file : ../gauss/part_dx004_r012//003040.dat
# output to iso000304.png
#
# processing file : ../gauss/part_dx004_r012//003050.dat
# output to iso000305.png
#
# processing file : ../gauss/part_dx004_r012//003060.dat
# output to iso000306.png
#
# processing file : ../gauss/part_dx004_r012//003070.dat
# output to iso000307.png
#
# processing file : ../gauss/part_dx004_r012//003080.dat
# output to iso000308.png
#
# processing file : ../gauss/part_dx004_r012//003090.dat
# output to iso000309.png
#
# processing file : ../gauss/part_dx004_r012//003100.dat
# output to iso000310.png
#
# processing file : ../gauss/part_dx004_r012//003110.dat
# output to iso000311.png
#
# processing file : ../gauss/part_dx004_r012//003120.dat
# output to iso000312.png
#
# processing file : ../gauss/part_dx004_r012//003130.dat
# output to iso000313.png
#
# processing file : ../gauss/part_dx004_r012//003140.dat
# output to iso000314.png
#
# processing file : ../gauss/part_dx004_r012//003150.dat
# output to iso000315.png
#
# processing file : ../gauss/part_dx004_r012//003160.dat
# output to iso000316.png
#
# processing file : ../gauss/part_dx004_r012//003170.dat
# output to iso000317.png
#
# processing file : ../gauss/part_dx004_r012//003180.dat
# output to iso000318.png
#
# processing file : ../gauss/part_dx004_r012//003190.dat
# output to iso000319.png
#
# processing file : ../gauss/part_dx004_r012//003200.dat
# output to iso000320.png
#
# processing file : ../gauss/part_dx004_r012//003210.dat
# output to iso000321.png
#
# processing file : ../gauss/part_dx004_r012//003220.dat
# output to iso000322.png
#
# processing file : ../gauss/part_dx004_r012//003230.dat
# output to iso000323.png
#
# processing file : ../gauss/part_dx004_r012//003240.dat
# output to iso000324.png
#
# processing file : ../gauss/part_dx004_r012//003250.dat
# output to iso000325.png
#
# processing file : ../gauss/part_dx004_r012//003260.dat
# output to iso000326.png
#
# processing file : ../gauss/part_dx004_r012//003270.dat
# output to iso000327.png
#
# processing file : ../gauss/part_dx004_r012//003280.dat
# output to iso000328.png
#
# processing file : ../gauss/part_dx004_r012//003290.dat
# output to iso000329.png
#
# processing file : ../gauss/part_dx004_r012//003300.dat
# output to iso000330.png
#
# processing file : ../gauss/part_dx004_r012//003310.dat
# output to iso000331.png
#
# processing file : ../gauss/part_dx004_r012//003320.dat
# output to iso000332.png
#
# processing file : ../gauss/part_dx004_r012//003330.dat
# output to iso000333.png
#
# processing file : ../gauss/part_dx004_r012//003340.dat
# output to iso000334.png
#
# processing file : ../gauss/part_dx004_r012//003350.dat
# output to iso000335.png
#
# processing file : ../gauss/part_dx004_r012//003360.dat
# output to iso000336.png
#
# processing file : ../gauss/part_dx004_r012//003370.dat
# output to iso000337.png
#
# processing file : ../gauss/part_dx004_r012//003380.dat
# output to iso000338.png
#
# processing file : ../gauss/part_dx004_r012//003390.dat
# output to iso000339.png
#
# processing file : ../gauss/part_dx004_r012//003400.dat
# output to iso000340.png
#
# processing file : ../gauss/part_dx004_r012//003410.dat
# output to iso000341.png
#
# processing file : ../gauss/part_dx004_r012//003420.dat
# output to iso000342.png
#
# processing file : ../gauss/part_dx004_r012//003430.dat
# output to iso000343.png
#
# processing file : ../gauss/part_dx004_r012//003440.dat
# output to iso000344.png
#
# processing file : ../gauss/part_dx004_r012//003450.dat
# output to iso000345.png
#
# processing file : ../gauss/part_dx004_r012//003460.dat
# output to iso000346.png
#
# processing file : ../gauss/part_dx004_r012//003470.dat
# output to iso000347.png
#
# processing file : ../gauss/part_dx004_r012//003480.dat
# output to iso000348.png
#
# processing file : ../gauss/part_dx004_r012//003490.dat
# output to iso000349.png
#
# processing file : ../gauss/part_dx004_r012//003500.dat
# output to iso000350.png
#
# processing file : ../gauss/part_dx004_r012//003510.dat
# output to iso000351.png
#
# processing file : ../gauss/part_dx004_r012//003520.dat
# output to iso000352.png
#
# processing file : ../gauss/part_dx004_r012//003530.dat
# output to iso000353.png
#
# processing file : ../gauss/part_dx004_r012//003540.dat
# output to iso000354.png
#
# processing file : ../gauss/part_dx004_r012//003550.dat
# output to iso000355.png
#
# processing file : ../gauss/part_dx004_r012//003560.dat
# output to iso000356.png
#
# processing file : ../gauss/part_dx004_r012//003570.dat
# output to iso000357.png
#
# processing file : ../gauss/part_dx004_r012//003580.dat
# output to iso000358.png
#
# processing file : ../gauss/part_dx004_r012//003590.dat
# output to iso000359.png
#
# processing file : ../gauss/part_dx004_r012//003600.dat
# output to iso000360.png
#
# processing file : ../gauss/part_dx004_r012//003610.dat
# output to iso000361.png
#
# processing file : ../gauss/part_dx004_r012//003620.dat
# output to iso000362.png
#
# processing file : ../gauss/part_dx004_r012//003630.dat
# output to iso000363.png
#
# processing file : ../gauss/part_dx004_r012//003640.dat
# output to iso000364.png
#
# processing file : ../gauss/part_dx004_r012//003650.dat
# output to iso000365.png
#
# processing file : ../gauss/part_dx004_r012//003660.dat
# output to iso000366.png
#
# processing file : ../gauss/part_dx004_r012//003670.dat
# output to iso000367.png
#
# processing file : ../gauss/part_dx004_r012//003680.dat
# output to iso000368.png
#
# processing file : ../gauss/part_dx004_r012//003690.dat
# output to iso000369.png
#
# processing file : ../gauss/part_dx004_r012//003700.dat
# output to iso000370.png
#
# processing file : ../gauss/part_dx004_r012//003710.dat
# output to iso000371.png
#
# processing file : ../gauss/part_dx004_r012//003720.dat
# output to iso000372.png
#
# processing file : ../gauss/part_dx004_r012//003730.dat
# output to iso000373.png
#
# processing file : ../gauss/part_dx004_r012//003740.dat
# output to iso000374.png
#
# processing file : ../gauss/part_dx004_r012//003750.dat
# output to iso000375.png
#
# processing file : ../gauss/part_dx004_r012//003760.dat
# output to iso000376.png
#
# processing file : ../gauss/part_dx004_r012//003770.dat
# output to iso000377.png
#
# processing file : ../gauss/part_dx004_r012//003780.dat
# output to iso000378.png
#
# processing file : ../gauss/part_dx004_r012//003790.dat
# output to iso000379.png
#
# processing file : ../gauss/part_dx004_r012//003800.dat
# output to iso000380.png
#
# processing file : ../gauss/part_dx004_r012//003810.dat
# output to iso000381.png
#
# processing file : ../gauss/part_dx004_r012//003820.dat
# output to iso000382.png
#
# processing file : ../gauss/part_dx004_r012//003830.dat
# output to iso000383.png
#
# processing file : ../gauss/part_dx004_r012//003840.dat
# output to iso000384.png
#
# processing file : ../gauss/part_dx004_r012//003850.dat
# output to iso000385.png
#
# processing file : ../gauss/part_dx004_r012//003860.dat
# output to iso000386.png
#
# processing file : ../gauss/part_dx004_r012//003870.dat
# output to iso000387.png
#
# processing file : ../gauss/part_dx004_r012//003880.dat
# output to iso000388.png
#
# processing file : ../gauss/part_dx004_r012//003890.dat
# output to iso000389.png
#
# processing file : ../gauss/part_dx004_r012//003900.dat
# output to iso000390.png
#
# processing file : ../gauss/part_dx004_r012//003910.dat
# output to iso000391.png
#
# processing file : ../gauss/part_dx004_r012//003920.dat
# output to iso000392.png
#
# processing file : ../gauss/part_dx004_r012//003930.dat
# output to iso000393.png
#
# processing file : ../gauss/part_dx004_r012//003940.dat
# output to iso000394.png
#
# processing file : ../gauss/part_dx004_r012//003950.dat
# output to iso000395.png
#
# processing file : ../gauss/part_dx004_r012//003960.dat
# output to iso000396.png
#
# processing file : ../gauss/part_dx004_r012//003970.dat
# output to iso000397.png
#
# processing file : ../gauss/part_dx004_r012//003980.dat
# output to iso000398.png
#
# processing file : ../gauss/part_dx004_r012//003990.dat
# output to iso000399.png
#
# processing file : ../gauss/part_dx004_r012//004000.dat
# output to iso000400.png
#
# processing file : ../gauss/part_dx004_r012//004010.dat
# output to iso000401.png
#
# processing file : ../gauss/part_dx004_r012//004020.dat
# output to iso000402.png
#
# processing file : ../gauss/part_dx004_r012//004030.dat
# output to iso000403.png
#
# processing file : ../gauss/part_dx004_r012//004040.dat
# output to iso000404.png
#
# processing file : ../gauss/part_dx004_r012//004050.dat
# output to iso000405.png
#
# processing file : ../gauss/part_dx004_r012//004060.dat
# output to iso000406.png
#
# processing file : ../gauss/part_dx004_r012//004070.dat
# output to iso000407.png
#
# processing file : ../gauss/part_dx004_r012//004080.dat
# output to iso000408.png
#
# processing file : ../gauss/part_dx004_r012//004090.dat
# output to iso000409.png
#
# processing file : ../gauss/part_dx004_r012//004100.dat
# output to iso000410.png
#
# processing file : ../gauss/part_dx004_r012//004110.dat
# output to iso000411.png
# processing file : ../gauss/part_dx004_r012//004120.dat
# output to iso000412.png
#
# processing file : ../gauss/part_dx004_r012//004130.dat
# output to iso000413.png
#
# processing file : ../gauss/part_dx004_r012//004140.dat
# output to iso000414.png
#
# processing file : ../gauss/part_dx004_r012//004150.dat
# output to iso000415.png
#
# processing file : ../gauss/part_dx004_r012//004160.dat
# output to iso000416.png
#
# processing file : ../gauss/part_dx004_r012//004170.dat
# output to iso000417.png
#
# processing file : ../gauss/part_dx004_r012//004180.dat
# output to iso000418.png
#
# processing file : ../gauss/part_dx004_r012//004190.dat
# output to iso000419.png
#
# processing file : ../gauss/part_dx004_r012//004200.dat
# output to iso000420.png
#
# processing file : ../gauss/part_dx004_r012//004210.dat
# output to iso000421.png
#
# processing file : ../gauss/part_dx004_r012//004220.dat
# output to iso000422.png
#
# processing file : ../gauss/part_dx004_r012//004230.dat
# output to iso000423.png
#
# processing file : ../gauss/part_dx004_r012//004240.dat
# output to iso000424.png
#
# processing file : ../gauss/part_dx004_r012//004250.dat
# output to iso000425.png
#
# processing file : ../gauss/part_dx004_r012//004260.dat
# output to iso000426.png
#
# processing file : ../gauss/part_dx004_r012//004270.dat
# output to iso000427.png
#
# processing file : ../gauss/part_dx004_r012//004280.dat
# output to iso000428.png
